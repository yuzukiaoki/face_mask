# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 32.37 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.6MB 9.0MB/s
# ...
#      |████████████████████████████████| 7.7MB 48.2MB/s
# ...
#      |████████████████████████████████| 81kB 12.1MB/s
# ...
#      |████████████████████████████████| 552kB 46.3MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.20.102 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Person' --type_csv train --limit 1500 #抓1500張圖片 #約要跑20分鐘
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Person.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 47158 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Person' --type_csv validation --limit 300
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Person.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 16 MB, 69005 KB/s, 0 seconds passed
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/YOLOv5/data/classes.txt  /content/ #若有其他classes 記得改 classes.txt

# %%
# !cp /content/drive/MyDrive/YOLOv5/data/convert_annotations.py  /content/OIDv4_ToolKit/
# !python /content/OIDv4_ToolKit/convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Person
# 100% 1500/1500 [01:19<00:00, 18.78it/s]
# Currently in subdirectory: validation
# Converting annotations for class:  Person
# 100% 300/300 [00:08<00:00, 35.99it/s]

# %%
# %cd /content/OID/Dataset/train/Vehicle registration plate
# Out:
# /content/OID/Dataset/train/Vehicle registration plate

# %%
# !ls
# Out:
# classes2.txt  drive   labels  OIDv4_ToolKit
# classes.txt   images  OID     sample_data

# %%
# !rm -r /content/OID/Dataset/train/'Person'/Label/

# %%
# !rm -r /content/OID/Dataset/validation/'Person'/Label/

# %%
# !mkdir -p images/train
# !mv /content/OID/Dataset/train/'Person'/*.jpg images/train #mv => MOVE

# %%
# !mkdir -p labels/train
# !mv /content/OID/Dataset/train/'Person'/*.txt labels/train

# %%
# !mkdir -p images/valid
# !mv /content/OID/Dataset/validation/'Person'/*.jpg images/valid

# %%
# !mkdir -p labels/valid
# !mv /content/OID/Dataset/validation/'Person'/*.txt labels/valid

# %%
# %cd /content/plate/labels/valid
# Out:
# /content/plate/labels/valid

# %%
# !ls

# %%
# !mkdir Person

# %%
# !mv images Person

# %%
# !mv labels Person

# %%
# !zip -r Person.zip Person

# %%
# !cp /content/Person.zip /content/drive/MyDrive/YOLOv5/data

# %% [markdown]
# # 新增區段
