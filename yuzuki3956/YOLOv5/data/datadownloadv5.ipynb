# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 19.37 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.6MB 12.4MB/s
# ...
#      |████████████████████████████████| 81kB 7.8MB/s
# ...
#      |████████████████████████████████| 7.6MB 64.0MB/s
# ...
#      |████████████████████████████████| 552kB 58.2MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.20.98 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Vehicle registration plate' --type_csv train --limit 1500 #抓1500張圖片 #約要跑20分鐘
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Vehicle registration plate.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 62892 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Vehicle registration plate' --type_csv validation --limit 300
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Vehicle registration plate.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 16 MB, 13474 KB/s, 1 seconds passed
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/YOLOv5/data/classes.txt  /content/ #若有其他classes 記得改 classes.txt

# %%
# !cp /content/drive/MyDrive/YOLOv5/data/convert_annotations.py  /content/OIDv4_ToolKit/
# !python /content/OIDv4_ToolKit/convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Vehicle registration plate
# Traceback (most recent call last):
#   File "/content/OIDv4_ToolKit/convert_annotations.py", line 52, in <module>
#     os.chdir("Label")
# FileNotFoundError: [Errno 2] No such file or directory: 'Label'

# %%
# %cd /content/OID/Dataset/train/Vehicle registration plate
# Out:
# /content/OID/Dataset/train/Vehicle registration plate

# %%
# !ls

# %%
# !rm -r /content/OID/Dataset/train/'Vehicle registration plate'/Label/

# %%
# !rm -r /content/OID/Dataset/validation/'Vehicle registration plate'/Label/

# %%
# !mkdir -p images/train
# !mv /content/OID/Dataset/train/'Vehicle registration plate'/*.jpg images/train #mv => MOVE

# %%
# !mkdir -p labels/train
# !mv /content/OID/Dataset/train/'Vehicle registration plate'/*.txt labels/train
# Out:
# mv: cannot stat '/content/OID/Dataset/train/Vehicle registration plate/*.txt': No such file or directory

# %%
# !mkdir -p images/valid
# !mv /content/OID/Dataset/validation/'Vehicle registration plate'/*.jpg images/valid
# Out:
# mv: cannot stat '/content/OID/Dataset/validation/Vehicle registration plate/*.jpg': No such file or directory

# %%
# !mkdir -p labels/valid
# !mv /content/OID/Dataset/validation/'Vehicle registration plate'/*.txt labels/valid
# Out:
# mv: cannot stat '/content/OID/Dataset/validation/Vehicle registration plate/*.txt': No such file or directory

# %%
# %cd /content/plate/labels/valid
# Out:
# /content/plate/labels/valid

# %%
# !ls

# %%
# !mkdir plate

# %%
# !mv images plate

# %%
# !mv labels plate

# %%
# !zip -r plate.zip plate
# Out:
#   adding: plate/ (stored 0%)
#   adding: plate/images/ (stored 0%)
#   adding: plate/images/valid/ (stored 0%)
#   adding: plate/images/valid/128a59bca025bed6.jpg (deflated 0%)
#   adding: plate/images/valid/3d98e3713783e82d.jpg (deflated 1%)
#   adding: plate/images/valid/28bd6c6b1050e055.jpg (deflated 0%)
#   adding: plate/images/valid/628a23a43f19c4db.jpg (deflated 0%)
#   adding: plate/images/valid/f5128e7a123b4fa8.jpg (deflated 0%)
#   adding: plate/images/valid/5021041c726b6ee4.jpg (deflated 0%)
#   adding: plate/images/valid/a54e7bb80448f3b0.jpg (deflated 0%)
#   adding: plate/images/valid/82b53fe7f9147c96.jpg (deflated 0%)
#   adding: plate/images/valid/49595029959689b7.jpg (deflated 0%)
#   adding: plate/images/valid/ae6724423f0d111a.jpg (deflated 0%)
#   adding: plate/images/valid/cdb1e8621d1c624e.jpg (deflated 1%)
#   adding: plate/images/valid/185d5dfa193c4ced.jpg (deflated 0%)
#   adding: plate/images/valid/a774a6f81fea258b.jpg (deflated 0%)
# ...

# %%
# !cp /content/plate.zip /content/drive/MyDrive/yolo/data/

# %% [markdown]
# # 新增區段
